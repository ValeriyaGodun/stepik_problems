# %% [markdown]
# ## Числовая угадайка
# **Описание проекта:** программа генерирует случайное число в диапазоне от 1 до 100 и просит пользователя угадать это число.
# Если догадка пользователя больше случайного числа, то программа должна вывести сообщение *'Слишком много, попробуйте еще раз'*.
# Если догадка меньше случайного числа, то программа должна вывести сообщение *'Слишком мало, попробуйте еще раз'*.
# Если пользователь угадывает число, то программа должна поздравить его и вывести сообщение *'Вы угадали, поздравляем!'*.
#
# **Составляющие проекта:**
# - Целые числа (тип int);
# - Переменные;
# - Ввод / вывод данных (функции input() и print());
# - Условный оператор (if/elif/else);
# - Цикл while;
# - Бесконечный цикл;
# - Операторы break, continue;
# - Работа с модулем random для генерации случайных чисел.

# %%
from random import *

# %%
def is_valid(number):
    if 1 < int(number) < 100:
        return True
    else:
        return False

# %%
print("Добро пожаловать в числовую угадайку")
print("Введите правую границу, из которой хотите угадывать числа")
n = int(input())
num = randrange(1, n)
counter = 0

while True:
    print(f"Введите число от 1 до {n}")
    num_user = input()
    if is_valid(num_user):
        num_user = int(num_user)
    else:
        print("А может быть все-таки введем целое число от 1 до {n}?")
        num_user = input()
        continue

    if num_user == num:
        print("Вы угадали, поздравляем! Хотите сыграть еще раз? (введите да или нет)")
        if input().lower() == "да":
            continue
        else:
            break
    elif num_user > num:
        print("Ваше число больше загаданного, попробуйте еще разок")
    elif num_user < num:
        print("Ваше число меньше загаданного, попробуйте еще разок")
    counter += 1

print(f"Число попыток, которые вы сделали: {counter}")
print("Спасибо, что играли в числовую угадайку. Еще увидимся...")

# %% [markdown]
# ## Магический шар 8
# **Описание проекта:** магический шар 8 (шар судьбы) — шуточный способ предсказывать будущее. Программа должна просить пользователя задать некий вопрос, чтобы случайным образом на него ответить.
#
# **Составляющие проекта:**
#
# - Целые числа (тип int);
# - Переменные;
# - Ввод / вывод данных (функции input() и print());
# - Условный оператор (if/elif/else);
# - Цикл while;
# - Бесконечный цикл;
# - Операторы break, continue;
# - Работа с модулем random для генерации случайных чисел.

# %%
from random import *

# %%
answer = ['Бесспорно', 'Предрешено', 'Никаких сомнений', 'Определённо да', 'Можешь быть уверен в этом', 'Мне кажется - да', 'Вероятнее всего', 'Хорошие перспективы',
'Знаки говорят - да', 'Да', 'Пока неясно, попробуй снова', 'Спроси позже', 'Лучше не рассказывать', 'Сейчас нельзя предсказать', 'Сконцентрируйся и спроси опять',
'Даже не думай', 'Мой ответ - нет', 'По моим данным - нет', 'Перспективы не очень хорошие', 'Весьма сомнительно']
print('Привет Мир, я магический шар, и я знаю ответ на любой твой вопрос.', '\n Как вас зовут?')
name = input()
print(f'Привет {name}')
flag = 'да'

while flag == 'да':
    print('Введите свой вопрос')
    question = input()
    print(choice(answer))
    print('Хотите задать еще вопрос? (введите да/нет)')
    flag = input().lower()
    print(flag)

print('Возвращайся если возникнут вопросы!')

# %% [markdown]
# ## Генератор безопасных паролей
# **Описание проекта**: программа генерирует заданное количество паролей и включает в себя умную настройку на длину пароля, а также на то, какие символы требуется в него включить, а какие исключить.
#
# **Составляющие проекта:**
#
# - Целые числа (тип int);
# - Переменные;
# - Ввод / вывод данных (функции input() и print());
# - Условный оператор (if/elif/else);
# - Цикл for;
# - Написание пользовательских функций;
# - Работа с модулем random для генерации случайных чисел.

# %%
from random import choice

# %%
digits = '0123456789'
uppercase_letters = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
lowercase_letters = 'abcdefghijklmnopqrstuvwxyz'
punctuation = '!#$%&*+-=?@^_'
chars = ''

print('Введите количество паролей для генерации (Введите число)')
count_pass = int(input())
print('Какой длины должен быть пароль? (Введите число)')
lenght_pass = int(input())
print('Включать ли цифры 0123456789? (Введите Да/Нет)')
digits_in_pass = input()
print('Включать ли прописные буквы ABCDEFGHIJKLMNOPQRSTUVWXYZ? (Введите Да/Нет)')
uppercase_letters_in_pass = input()
print('Включать ли строчные буквы abcdefghijklmnopqrstuvwxyz? (Введите Да/Нет)')
lowercase_letters_in_pass  = input()
print('Включать ли символы !#$%&*+-=?@^_? (Введите Да/Нет)')
punctuation_in_pass = input()
print('Исключать ли неоднозначные символы il1Lo0O? (Введите Да/Нет)')
same_symbl_in_pass = input()

# %%
if digits_in_pass.lower() == 'да':
    chars += digits
if uppercase_letters_in_pass.lower() == 'да':
    chars += uppercase_letters
if lowercase_letters_in_pass .lower() == 'да':
    chars += lowercase_letters
if punctuation_in_pass.lower() == 'да':
    chars += punctuation
if same_symbl_in_pass == 'да':
    for el in 'il1Lo0O':
        chars = chars.replace(el, '')

# %%
def generate_password(length, chars):
    password = ''
    for i in range(length):
        password += choice(chars)
    return password

# %%
for i in range(count_pass):
    print(f'Пароль {count_pass}: {generate_password(lenght_pass, chars)}')

# %% [markdown]
# ## Шифр Цезаря
# **Описание проекта:** требуется написать программу, способную шифровать и дешифровать текст в соответствии с алгоритмом Цезаря. Она должна запрашивать у пользователя следующие данные:
#
# - направление: шифрование или дешифрование;
# - язык алфавита: русский или английский;
# - шаг сдвига (со сдвигом вправо).
#
# *Примечание 1.* Считайте, что в русском языке 32 буквы (буква ё отсутствует).
# *Примечание 2.* Неалфавитные символы — знаки препинания, пробелы, цифры — не меняются.
# *Примечание 3.* Сохраните регистр символов. Например, текст: "Умом Россию не понять" при сдвиге на одну позицию вправо будет преобразован в: "Фнпн Спттйя ож рпоауэ".
#
# **Составляющие проекта:**
#
# - Целые числа (тип int);
# - Модульная арифметика;
# - Переменные;
# - Ввод / вывод данных (функции input() и print());
# - Условный оператор (if/elif/else);
# - Цикл for/while;
# - Строковые методы.

# %%
print('Вы хотите зашифровать текст или дешифровать? (введите 1, если хотите зашифровать, и 2 - если дешифровать)')
code_decode = int(input())
print('На каком языке введённый вами текст? (введите 1, если русский, и 2 - если английский)')
initial_language = int(input())
print('Какой шаг сдвига (вправо) вы хотите использовать? (введите число)')
initial_rotate = int(input())
print('Введите текст, который хотите зашифровать или дешифровать')
initial_text = input()

# %%
if initial_language == 1:
    n = 32
    letter_up = 'А'
    letter_down = 'а'
    
elif initial_language == 2:
    n = 26
    letter_up = 'A'
    letter_down = 'a'

# %%
def encoding(key):
    res = []

    for el in initial_text:
        if el.isalpha():

            if el.isupper():
                res.append(
                    chr(ord(letter_up) + (ord(el) + key - ord(letter_up)) % n)
                )

            if el.islower():
                res.append(
                    chr(ord(letter_down) + (ord(el) + key - ord(letter_down)) % n)
                )

        else:
            res.append(el)

    return ''.join(res)

# %%
def code(rotate):
    key = rotate
    return encoding(key)

def decode(rotate):
    key = -rotate
    return encoding(key)

# %%
if code_decode == 1:
    print(code(initial_rotate))
elif code_decode == 2:
    print(decode(initial_rotate))

# %% [markdown]
# **Аве, Цезарь** 🌶️
# На вход программе подаётся строка текста на английском языке, в которой нужно зашифровать все слова. Каждое слово строки следует зашифровать с помощью шифра Цезаря (циклического сдвига на длину этого слова). Строчные буквы при этом остаются строчными, а прописные – прописными. Гарантируется, что между различными словами присутствует один пробел.

# %%
initial_text = input().split()

text = []

for el in initial_text:
    for i in range(0, len(el)):
        if el[i].isalpha():
            text.append(el[i])
    text.append(" ")
res = "".join(text)

initial_rotate = [len(el) for el in res.split()]

LETTER_UP = "A"
LETTER_DOWN = "a"

# %%
def encoding():
    res = []

    for el in initial_text:
        for i in range(0,len(el)):

          if el[i].isalpha():

              if el[i].isupper():
                res.append(
                    chr(ord(LETTER_UP) + (ord(el[i]) + initial_rotate[initial_text.index(el)] - ord(LETTER_UP)) % 26)
                )

              if el[i].islower():
                res.append(
                    chr(ord(LETTER_DOWN) + (ord(el[i]) + initial_rotate[initial_text.index(el)] - ord(LETTER_DOWN)) % 26)
                )

          else:
            res.append(el[i])

        res.append(' ')

    res.pop(-1)

    return ''.join(res)

print(encoding())

# %%
def encoding():
    res = []

    for el in initial_text:
        for i in range(0, len(el)):

            if el[i].isalpha():

                if el[i].isupper():
                    res.append(
                        chr(
                            ord(LETTER_UP)
                            + (
                                ord(el[i])
                                + initial_rotate[initial_text.index(el)]
                                - ord(LETTER_UP)
                            )
                            % 26
                        )
                    )

                if el[i].islower():
                    res.append(
                        chr(
                            ord(LETTER_DOWN)
                            + (
                                ord(el[i])
                                + initial_rotate[initial_text.index(el)]
                                - ord(LETTER_DOWN)
                            )
                            % 26
                        )
                    )

            else:
                res.append(el[i])

        res.append(" ")

    res.pop(-1)

    return "".join(res)

print(encoding())

# %%
alphabet = 'abcdefghijklmnopqrstuvwxyz'

s_old = input()
words = s_old.split()  # разбиваем строку на слова

s_new = ""
for word in words:
    shift = sum([int(letter.lower() in alphabet) for letter in word])  # считаем длину каждого слова

    for letter in word:
        if letter in alphabet:  # проверяем, что это строчная буква
            old_letter_position = alphabet.index(letter)
            letter = alphabet[(old_letter_position + shift) % 26]

        elif letter.lower() in alphabet:  # проверяем, что это прописная буква
            old_letter_position = alphabet.index(letter.lower())
            letter = alphabet[(old_letter_position + shift) % 26].upper()

        s_new += letter

    s_new += " "

print(s_new)

# %% [markdown]
# ## Угадайка слов
# **Описание проекта:** программа загадывает слово, а пользователь должен его угадать. Изначально все буквы слова неизвестны. Также рисуется виселица с петлей. Пользователь предлагает букву, которая может входить в это слово. Если такая буква есть в слове, то программа ставит букву столько раз, сколько она встречается в слове. Если такой буквы нет, к виселице добавляется круг в петле, изображающий голову. Пользователь продолжает отгадывать буквы до тех пор, пока не отгадает всё слово. За каждую неудачную попытку добавляется еще одна часть туловища висельника (обычно их 6: голова, туловище, 2 руки и 2 ноги).
#
# **Составляющие проекта:**
#
# - Целые числа (тип int);
# - Переменные;
# - Ввод / вывод данных (функции input() и print());
# - Условный оператор (if/elif/else);
# - Цикл while;
# - Бесконечный цикл;
# - Операторы break, continue;
# - Создание пользовательских функций;
# - Списочные выражения;
# - Работа с модулем random для генерации случайных чисел.

# %%
from random import *

# %%
word_list = ["человек", "слово", "лицо", "дверь", "земля", "работа", "ребенок", "история", "женщина"]

# %%
def get_word(words_list):
    word = choice(words_list).upper()
    return word

# %%
# функция получения текущего состояния
def display_hangman(tries):
    stages = [  # финальное состояние: голова, торс, обе руки, обе ноги
        """
                   --------
                   |      |
                   |      O
                   |     \\|/
                   |      |
                   |     / \\
                   -
                """,
        # голова, торс, обе руки, одна нога
        """
                   --------
                   |      |
                   |      O
                   |     \\|/
                   |      |
                   |     / 
                   -
                """,
        # голова, торс, обе руки
        """
                   --------
                   |      |
                   |      O
                   |     \\|/
                   |      |
                   |      
                   -
                """,
        # голова, торс и одна рука
        """
                   --------
                   |      |
                   |      O
                   |     \\|
                   |      |
                   |     
                   -
                """,
        # голова и торс
        """
                   --------
                   |      |
                   |      O
                   |      |
                   |      |
                   |     
                   -
                """,
        # голова
        """
                   --------
                   |      |
                   |      O
                   |    
                   |      
                   |     
                   -
                """,
        # начальное состояние
        """
                   --------
                   |      |
                   |      
                   |    
                   |      
                   |     
                   -
                """,
    ]
    return stages[tries]

# %%
def play(word):
    # тело функции
    word_completion = '_' * len(word)  # строка, содержащая символы _ на каждую букву задуманного слова
    #guessed = False                    # сигнальная метка
    guessed_letters = []               # список уже названных букв
    guessed_words = []                 # список уже названных слов
    tries = 6                          # количество попыток


    print('Давайте играть в угадайку слов!')
    print(display_hangman(tries))
    print(word_completion)

    while tries != 0:
        print('Введите букву или слово')
        input_letter = input().upper()
        
        if not input_letter.isalpha():
            print('Вы ошиблись. Требуется ввести букву или слово.')
        else: 

            if input_letter in guessed_letters or input_letter in guessed_words:
                print('Уже называли. Попробуйте еще раз!')
                input_letter = input().upper()

            if len(input_letter) == 1:
                guessed_letters.append(input_letter)
            else: 
                guessed_words.append(input_letter)

            if input_letter == word:
                print('Поздравляем, вы угадали слово! Вы победили!')
                break
            
            elif input_letter in word:

                list_ind = [i for i in range(len(word)) if word[i] == input_letter]

                for el in list_ind:
                    s = word_completion
                    li = list(s)
                    li[el] = input_letter
                    word_completion = ''.join(li)  

                print('Вы угадали букву!')
                print(word_completion)      

            else:
                print('Вы не угадали!')
                tries -= 1
                print(display_hangman(tries))
                
                if tries == 0:
                    print(f'Вы проиграли. Загаданное слово {word}')
                    break

# %%
word = get_word(word_list)
play(word)

print('Хотите сыграть еще раз? (Введите да или нет)')

while input().upper() == 'ДА':
    word = get_word(word_list)
    play(word)
# Out:
# Давайте играть в угадайку слов!
#
#                    --------
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                    -
#
# ______
# Введите букву или слово
# Вы угадали букву!
# _А___А
# Введите букву или слово
# Вы угадали букву!
# _АБ__А
# Введите букву или слово
# Вы не угадали!
#
#                    --------
#                    |      |
#                    |      O
#                    |
#                    |
#                    |
#                    -
#
# Введите букву или слово
# Вы не угадали!
#
#                    --------
#                    |      |
#                    |      O
#                    |      |
#                    |      |
#                    |
#                    -
#
# Введите букву или слово
# Вы не угадали!
#
#                    --------
#                    |      |
#                    |      O
#                    |     \|
#                    |      |
# ...
